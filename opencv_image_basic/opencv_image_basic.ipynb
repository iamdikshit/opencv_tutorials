# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
#Let Read the image file using OpenCV object i.e cv2
img = cv2.imread('data/3.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)
# because cv2 using BGR pattern

# %%
fixed_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fixed_img)

# %%
fixed_img.shape
# Out:
# (400, 600, 3)

# %%
img_gray = cv2.imread('data/3.jpg', cv2.IMREAD_GRAYSCALE)

# %%
fixed_img_gray = cv2.cvtColor(img_gray,cv2.COLOR_BGR2RGB)
plt.imshow(fixed_img_gray)

# %%
plt.imshow(fixed_img,cmap='gray')

# %%
img_resized = cv2.resize(fixed_img,(200,150))
plt.imshow(img_resized)

# %%
new_img = cv2.flip(fixed_img,0) # 0 will fill at x-axis and 1 will filp at y-axis 
plt.imshow(new_img)

# %%
fig = plt.figure(figsize = (2,2))
ax = fig.add_subplot(111)
ax.imshow(fixed_img)
